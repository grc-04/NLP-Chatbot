# %% [markdown]
# <a href="https://colab.research.google.com/github/grc-04/NLP-Chatbot/blob/main/Chatbot_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPORTING LIBRAIRES 

import json #to work with JSON data
import string #Provides access to several potentially valuable constants
import random #implements pseudo-random number generators
import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer
import tensorflow as tF #A multidimensional array of elements is represented by this symbol.
from tensorflow.keras import Sequential #Sequential groups a linear stack of layers into a tf.keras.Model
from tensorflow.keras.layers import Dense, Dropout

nltk.download("punkt")# required package for tokenization
nltk.download("wordnet")# word database
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
#CREATING A JSON FILE

##JSON file that lists all the possible outcomes of user interactions with our chatbot
##We first need a set of tags that users can use to categorize their queries. These tags include name, age, and many others. 
##Every new tag would require a unique pattern. This trend identification helps the chatbot train itself on how people would query it, making it more responsive
##Then chatbot will return the pre-programmed answers when asked the designated questions. 

ourData = {"intents": [

             {"tag": "age",
              "patterns": ["how old are you?","what is your age?","when is your birthday?"],
              "responses": ["I am 2 years old and my birthday was yesterday"]
             },
              {"tag": "greeting",
              "patterns": [ "Hi", "Hello", "Hey", "Heya", "Namaste"],
              "responses": ["Hi there", "Hello", "Hi :)", "Namaste"],
             },
              {"tag": "goodbye",
              "patterns": [ "bye", "later", "Bye Bye"],
              "responses": ["Bye", "take care", "Sayonara"]
             },
             {"tag": "name",
              "patterns": ["what's your name?", "who are you?", "what are you called?", "How do I call you?"],
              "responses": ["I have no name yet," "You can give me one, and I will appreciate it"]
             }

]}

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
#PROCESSING DATA

##Creating vocabulary of all the terms used in the patterns, list of tag classes, list of all the patterns in the intents file, and all the related tags for each pattern before creating our training data

lm = WordNetLemmatizer() #for getting words
# lists
ourClasses = []
newWords = []
documentX = []
documentY = []
# Each intent is tokenized into words and the patterns and their associated tags are added to their respective lists.
for intent in ourData["intents"]:
    for pattern in intent["patterns"]:
        ourTokens = nltk.word_tokenize(pattern)
        newWords.extend(ourTokens)
        documentX.append(pattern)
        documentY.append(intent["tag"])
    
    
    if intent["tag"] not in ourClasses:# add unexisting tags to their respective classes
        ourClasses.append(intent["tag"])

newWords = [lm.lemmatize(word.lower()) 
for word in newWords if word not in string.punctuation] # set words to lowercase if not in punctuation
newWords = sorted(set(newWords))# sorting words
ourClasses = sorted(set(ourClasses))# sorting classes

# %%
print(newWords)
print(ourClasses)
# Out:
# ["'s", 'age', 'are', 'birthday', 'bye', 'call', 'called', 'do', 'hello', 'hey', 'heya', 'hi', 'how', 'i', 'is', 'later', 'namaste', 'name', 'old', 'what', 'when', 'who', 'you', 'your']
# ['age', 'goodbye', 'greeting', 'name']

# %%
#DESIGNING A NEURAL NETWORK MODEL 

##Neural networks only understand numerical values 
##Transforming our data into numerical values using Bag of Words (BoW) encoding system 

trainingData = [] # training list array
outEmpty = [0] * len(ourClasses)

#BOW model
for idx, doc in enumerate(documentX):
    bagOfwords = []
    text = lm.lemmatize(doc.lower())
    for word in newWords:
        bagOfwords.append(1) if word in text else bagOfwords.append(0)
    
    outputRow = list(outEmpty)
    outputRow[ourClasses.index(documentY[idx])] = 1
    trainingData.append([bagOfwords, outputRow])

random.shuffle(trainingData)
trainingData = np.array(trainingData, dtype=object) #coverting our data into an array afterv shuffling

x = np.array(list(trainingData[:, 0])) #first trainig phase
y = np.array(list(trainingData[:, 1])) #second training phase

# %%
#Designing a neural network to feed our training data 
##Model will select an appropriate response from the tag associated with a given feature

#defining some parameters
iShape = (len(x[0]),)
oShape = len(y[0])

#the deep learning model
ourNewModel = Sequential() #sequential model is approprita for a single stack of layers
ourNewModel.add(Dense(128, input_shape=iShape, activation="relu")) #Dense fn adds an output layer
ourNewModel.add(Dropout(0.5)) #dropout is used to enhance the viz perception of input neurons 
ourNewModel.add(Dense(64, activation="relu")) 
ourNewModel.add(Dropout(0.3))
ourNewModel.add(Dense(oShape, activation = "softmax"))
md = tF.keras.optimizers.legacy.Adam(learning_rate=0.01, decay=1e-6) #callable that returns the value to be used with no arguments
ourNewModel.compile(loss='categorical_crossentropy',
              optimizer=md,
              metrics=["accuracy"]) #improves the numerical stability and pushes the computation of the probability distribution into the categorical crossentropy loss function.

print(ourNewModel.summary()) #Output model in summary 
ourNewModel.fit(x, y, epochs=200, verbose=1) #choosing the output as verbose instead of simple, epochs - no. of repetitions for a training set
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               3200
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 11,716
# Trainable params: 11,716
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.3047 - accuracy: 0.4667
# Epoch 2/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3362 - accuracy: 0.2667
# Epoch 3/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1789 - accuracy: 0.6000
# Epoch 4/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.9874 - accuracy: 0.8000
# Epoch 5/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0151 - accuracy: 0.8000
# Epoch 6/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.8607 - accuracy: 0.8000
# Epoch 7/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6815 - accuracy: 0.8000
# Epoch 8/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6679 - accuracy: 0.8667
# Epoch 9/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4662 - accuracy: 0.8667
# Epoch 10/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.3769 - accuracy: 0.9333
# Epoch 11/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2976 - accuracy: 1.0000
# Epoch 12/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2066 - accuracy: 0.9333
# Epoch 13/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1645 - accuracy: 0.9333
# Epoch 14/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1080 - accuracy: 1.0000
# Epoch 15/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1731 - accuracy: 0.9333
# Epoch 16/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0738 - accuracy: 1.0000
# Epoch 17/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0379 - accuracy: 1.0000
# Epoch 18/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 19/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0556 - accuracy: 1.0000
# Epoch 20/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0661 - accuracy: 0.9333
# Epoch 21/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0288 - accuracy: 1.0000
# Epoch 22/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0285 - accuracy: 1.0000
# Epoch 23/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0597 - accuracy: 1.0000
# Epoch 24/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 25/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0387 - accuracy: 1.0000
# Epoch 26/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 27/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 28/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 29/200
# 1/1 [==============================] - 0s 11ms/step - loss: 7.0161e-04 - accuracy: 1.0000
# Epoch 30/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 31/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 32/200
# 1/1 [==============================] - 0s 11ms/step - loss: 2.5349e-04 - accuracy: 1.0000
# Epoch 33/200
# 1/1 [==============================] - 0s 10ms/step - loss: 5.4215e-04 - accuracy: 1.0000
# Epoch 34/200
# 1/1 [==============================] - 0s 11ms/step - loss: 2.0227e-04 - accuracy: 1.0000
# Epoch 35/200
# 1/1 [==============================] - 0s 11ms/step - loss: 4.2808e-04 - accuracy: 1.0000
# Epoch 36/200
# 1/1 [==============================] - 0s 10ms/step - loss: 7.6118e-04 - accuracy: 1.0000
# Epoch 37/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 38/200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.7962e-04 - accuracy: 1.0000
# Epoch 39/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0572 - accuracy: 0.9333
# Epoch 40/200
# 1/1 [==============================] - 0s 11ms/step - loss: 5.1485e-04 - accuracy: 1.0000
# Epoch 41/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 42/200
# 1/1 [==============================] - 0s 11ms/step - loss: 7.5795e-04 - accuracy: 1.0000
# Epoch 43/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 44/200
# 1/1 [==============================] - 0s 11ms/step - loss: 2.9642e-04 - accuracy: 1.0000
# Epoch 45/200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.5170e-04 - accuracy: 1.0000
# Epoch 46/200
# 1/1 [==============================] - 0s 11ms/step - loss: 5.1621e-05 - accuracy: 1.0000
# Epoch 47/200
# 1/1 [==============================] - 0s 10ms/step - loss: 6.6233e-04 - accuracy: 1.0000
# Epoch 48/200
# 1/1 [==============================] - 0s 10ms/step - loss: 3.1159e-05 - accuracy: 1.0000
# Epoch 49/200
# 1/1 [==============================] - 0s 10ms/step - loss: 4.8115e-05 - accuracy: 1.0000
# Epoch 50/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 51/200
# 1/1 [==============================] - 0s 10ms/step - loss: 3.0427e-05 - accuracy: 1.0000
# Epoch 52/200
# 1/1 [==============================] - 0s 12ms/step - loss: 6.8393e-04 - accuracy: 1.0000
# Epoch 53/200
# 1/1 [==============================] - 0s 11ms/step - loss: 4.1115e-04 - accuracy: 1.0000
# Epoch 54/200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.6906e-05 - accuracy: 1.0000
# Epoch 55/200
# 1/1 [==============================] - 0s 15ms/step - loss: 1.2465e-04 - accuracy: 1.0000
# Epoch 56/200
# 1/1 [==============================] - 0s 10ms/step - loss: 3.7536e-04 - accuracy: 1.0000
# Epoch 57/200
# 1/1 [==============================] - 0s 10ms/step - loss: 4.7383e-05 - accuracy: 1.0000
# Epoch 58/200
# 1/1 [==============================] - 0s 11ms/step - loss: 9.3804e-05 - accuracy: 1.0000
# Epoch 59/200
# 1/1 [==============================] - 0s 11ms/step - loss: 4.0200e-05 - accuracy: 1.0000
# Epoch 60/200
# 1/1 [==============================] - 0s 11ms/step - loss: 5.3488e-04 - accuracy: 1.0000
# Epoch 61/200
# 1/1 [==============================] - 0s 10ms/step - loss: 7.7507e-05 - accuracy: 1.0000
# Epoch 62/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 63/200
# 1/1 [==============================] - 0s 13ms/step - loss: 9.6036e-04 - accuracy: 1.0000
# Epoch 64/200
# 1/1 [==============================] - 0s 12ms/step - loss: 3.2771e-04 - accuracy: 1.0000
# Epoch 65/200
# 1/1 [==============================] - 0s 21ms/step - loss: 1.7229e-05 - accuracy: 1.0000
# Epoch 66/200
# 1/1 [==============================] - 0s 10ms/step - loss: 2.8038e-04 - accuracy: 1.0000
# Epoch 67/200
# 1/1 [==============================] - 0s 11ms/step - loss: 6.5847e-05 - accuracy: 1.0000
# Epoch 68/200
# 1/1 [==============================] - 0s 11ms/step - loss: 5.4676e-04 - accuracy: 1.0000
# Epoch 69/200
# 1/1 [==============================] - 0s 11ms/step - loss: 8.8870e-04 - accuracy: 1.0000
# Epoch 70/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 71/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 72/200
# 1/1 [==============================] - 0s 14ms/step - loss: 5.8466e-05 - accuracy: 1.0000
# Epoch 73/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 74/200
# 1/1 [==============================] - 0s 10ms/step - loss: 4.9450e-05 - accuracy: 1.0000
# Epoch 75/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 76/200
# 1/1 [==============================] - 0s 11ms/step - loss: 8.7666e-05 - accuracy: 1.0000
# Epoch 77/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.5057e-04 - accuracy: 1.0000
# Epoch 78/200
# 1/1 [==============================] - 0s 10ms/step - loss: 9.3538e-06 - accuracy: 1.0000
# Epoch 79/200
# 1/1 [==============================] - 0s 10ms/step - loss: 5.4678e-04 - accuracy: 1.0000
# Epoch 80/200
# 1/1 [==============================] - 0s 10ms/step - loss: 8.1536e-06 - accuracy: 1.0000
# Epoch 81/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 82/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.7678e-04 - accuracy: 1.0000
# Epoch 83/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0328 - accuracy: 1.0000
# Epoch 84/200
# 1/1 [==============================] - 0s 12ms/step - loss: 8.3908e-05 - accuracy: 1.0000
# Epoch 85/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.7373e-04 - accuracy: 1.0000
# Epoch 86/200
# 1/1 [==============================] - 0s 9ms/step - loss: 2.1646e-04 - accuracy: 1.0000
# Epoch 87/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4812e-04 - accuracy: 1.0000
# Epoch 88/200
# 1/1 [==============================] - 0s 10ms/step - loss: 3.6171e-05 - accuracy: 1.0000
# Epoch 89/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4787e-04 - accuracy: 1.0000
# Epoch 90/200
# 1/1 [==============================] - 0s 12ms/step - loss: 4.2289e-05 - accuracy: 1.0000
# Epoch 91/200
# 1/1 [==============================] - 0s 12ms/step - loss: 7.3867e-05 - accuracy: 1.0000
# Epoch 92/200
# 1/1 [==============================] - 0s 11ms/step - loss: 4.4021e-04 - accuracy: 1.0000
# Epoch 93/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.3899e-05 - accuracy: 1.0000
# Epoch 94/200
# 1/1 [==============================] - 0s 10ms/step - loss: 4.2711e-05 - accuracy: 1.0000
# Epoch 95/200
# 1/1 [==============================] - 0s 10ms/step - loss: 8.0985e-05 - accuracy: 1.0000
# Epoch 96/200
# 1/1 [==============================] - 0s 16ms/step - loss: 9.6898e-04 - accuracy: 1.0000
# Epoch 97/200
# 1/1 [==============================] - 0s 17ms/step - loss: 2.1584e-04 - accuracy: 1.0000
# Epoch 98/200
# 1/1 [==============================] - 0s 10ms/step - loss: 6.6782e-05 - accuracy: 1.0000
# Epoch 99/200
# 1/1 [==============================] - 0s 11ms/step - loss: 4.1537e-05 - accuracy: 1.0000
# Epoch 100/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.5665e-04 - accuracy: 1.0000
# Epoch 101/200
# 1/1 [==============================] - 0s 21ms/step - loss: 5.1574e-04 - accuracy: 1.0000
# Epoch 102/200
# 1/1 [==============================] - 0s 13ms/step - loss: 7.2243e-04 - accuracy: 1.0000
# Epoch 103/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 104/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 105/200
# 1/1 [==============================] - 0s 17ms/step - loss: 1.4565e-04 - accuracy: 1.0000
# Epoch 106/200
# 1/1 [==============================] - 0s 11ms/step - loss: 2.7115e-04 - accuracy: 1.0000
# Epoch 107/200
# 1/1 [==============================] - 0s 17ms/step - loss: 3.8583e-04 - accuracy: 1.0000
# Epoch 108/200
# 1/1 [==============================] - 0s 20ms/step - loss: 1.5204e-04 - accuracy: 1.0000
# Epoch 109/200
# 1/1 [==============================] - 0s 18ms/step - loss: 6.7428e-05 - accuracy: 1.0000
# Epoch 110/200
# 1/1 [==============================] - 0s 22ms/step - loss: 6.4366e-05 - accuracy: 1.0000
# Epoch 111/200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0226 - accuracy: 1.0000
# Epoch 112/200
# 1/1 [==============================] - 0s 20ms/step - loss: 3.2589e-04 - accuracy: 1.0000
# Epoch 113/200
# 1/1 [==============================] - 0s 22ms/step - loss: 1.0090e-04 - accuracy: 1.0000
# Epoch 114/200
# 1/1 [==============================] - 0s 21ms/step - loss: 8.5958e-05 - accuracy: 1.0000
# Epoch 115/200
# 1/1 [==============================] - 0s 33ms/step - loss: 6.5286e-05 - accuracy: 1.0000
# Epoch 116/200
# 1/1 [==============================] - 0s 25ms/step - loss: 2.3174e-04 - accuracy: 1.0000
# Epoch 117/200
# 1/1 [==============================] - 0s 22ms/step - loss: 4.5324e-04 - accuracy: 1.0000
# Epoch 118/200
# 1/1 [==============================] - 0s 18ms/step - loss: 3.2665e-04 - accuracy: 1.0000
# Epoch 119/200
# 1/1 [==============================] - 0s 16ms/step - loss: 4.0335e-04 - accuracy: 1.0000
# Epoch 120/200
# 1/1 [==============================] - 0s 22ms/step - loss: 1.4765e-05 - accuracy: 1.0000
# Epoch 121/200
# 1/1 [==============================] - 0s 21ms/step - loss: 7.5576e-05 - accuracy: 1.0000
# Epoch 122/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 123/200
# 1/1 [==============================] - 0s 24ms/step - loss: 8.1800e-04 - accuracy: 1.0000
# Epoch 124/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 125/200
# 1/1 [==============================] - 0s 12ms/step - loss: 2.8379e-04 - accuracy: 1.0000
# Epoch 126/200
# 1/1 [==============================] - 0s 15ms/step - loss: 3.0146e-04 - accuracy: 1.0000
# Epoch 127/200
# 1/1 [==============================] - 0s 10ms/step - loss: 7.0410e-06 - accuracy: 1.0000
# Epoch 128/200
# 1/1 [==============================] - 0s 11ms/step - loss: 4.2033e-05 - accuracy: 1.0000
# Epoch 129/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.9153e-04 - accuracy: 1.0000
# Epoch 130/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.3916e-04 - accuracy: 1.0000
# Epoch 131/200
# 1/1 [==============================] - 0s 10ms/step - loss: 2.0312e-05 - accuracy: 1.0000
# Epoch 132/200
# 1/1 [==============================] - 0s 12ms/step - loss: 8.8530e-06 - accuracy: 1.0000
# Epoch 133/200
# 1/1 [==============================] - 0s 21ms/step - loss: 6.1129e-05 - accuracy: 1.0000
# Epoch 134/200
# 1/1 [==============================] - 0s 12ms/step - loss: 2.6510e-05 - accuracy: 1.0000
# Epoch 135/200
# 1/1 [==============================] - 0s 15ms/step - loss: 2.4698e-05 - accuracy: 1.0000
# Epoch 136/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.3398e-05 - accuracy: 1.0000
# Epoch 137/200
# 1/1 [==============================] - 0s 17ms/step - loss: 3.2057e-05 - accuracy: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 20ms/step - loss: 6.1859e-05 - accuracy: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 26ms/step - loss: 1.9726e-04 - accuracy: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 11ms/step - loss: 7.0771e-05 - accuracy: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 13ms/step - loss: 3.1630e-06 - accuracy: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 11ms/step - loss: 5.5312e-06 - accuracy: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 11ms/step - loss: 5.3959e-05 - accuracy: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.9165e-04 - accuracy: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 14ms/step - loss: 1.0554e-05 - accuracy: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 14ms/step - loss: 1.2723e-05 - accuracy: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 21ms/step - loss: 1.6338e-05 - accuracy: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 12ms/step - loss: 2.9607e-04 - accuracy: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 13ms/step - loss: 2.9193e-04 - accuracy: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 28ms/step - loss: 1.5147e-05 - accuracy: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 30ms/step - loss: 1.3660e-05 - accuracy: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 16ms/step - loss: 4.5140e-06 - accuracy: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 21ms/step - loss: 1.9915e-05 - accuracy: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 16ms/step - loss: 2.6161e-05 - accuracy: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 20ms/step - loss: 2.0415e-05 - accuracy: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 23ms/step - loss: 4.9152e-04 - accuracy: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 14ms/step - loss: 2.5390e-05 - accuracy: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 15ms/step - loss: 6.2383e-05 - accuracy: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 19ms/step - loss: 2.4548e-05 - accuracy: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 22ms/step - loss: 5.1498e-06 - accuracy: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 24ms/step - loss: 1.1841e-05 - accuracy: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 24ms/step - loss: 4.5172e-05 - accuracy: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 11ms/step - loss: 6.2348e-05 - accuracy: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 32ms/step - loss: 1.3359e-04 - accuracy: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 29ms/step - loss: 1.2875e-06 - accuracy: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 18ms/step - loss: 1.0885e-04 - accuracy: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 15ms/step - loss: 7.4023e-05 - accuracy: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 21ms/step - loss: 1.3194e-04 - accuracy: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 21ms/step - loss: 4.8283e-05 - accuracy: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 15ms/step - loss: 3.4967e-06 - accuracy: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 16ms/step - loss: 1.1545e-04 - accuracy: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 16ms/step - loss: 1.5313e-05 - accuracy: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 19ms/step - loss: 9.4729e-06 - accuracy: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 18ms/step - loss: 2.2482e-05 - accuracy: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 17ms/step - loss: 2.4698e-05 - accuracy: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 18ms/step - loss: 6.9907e-05 - accuracy: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 23ms/step - loss: 1.1626e-05 - accuracy: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 17ms/step - loss: 4.9777e-05 - accuracy: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 18ms/step - loss: 1.7733e-04 - accuracy: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 14ms/step - loss: 1.7082e-04 - accuracy: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 17ms/step - loss: 1.8992e-05 - accuracy: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 18ms/step - loss: 3.5327e-05 - accuracy: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 18ms/step - loss: 1.5767e-04 - accuracy: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 20ms/step - loss: 1.2985e-05 - accuracy: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 15ms/step - loss: 2.9943e-04 - accuracy: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 19ms/step - loss: 8.3661e-04 - accuracy: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 18ms/step - loss: 7.7816e-05 - accuracy: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 14ms/step - loss: 4.9823e-04 - accuracy: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 21ms/step - loss: 9.7476e-05 - accuracy: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 18ms/step - loss: 1.2699e-05 - accuracy: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 23ms/step - loss: 2.0533e-05 - accuracy: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 16ms/step - loss: 1.9709e-06 - accuracy: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 15ms/step - loss: 1.1865e-05 - accuracy: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 13ms/step - loss: 2.5420e-04 - accuracy: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 21ms/step - loss: 4.3328e-05 - accuracy: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 20ms/step - loss: 1.6387e-05 - accuracy: 1.0000
# Epoch 197/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.7881e-06 - accuracy: 1.0000
# Epoch 198/200
# 1/1 [==============================] - 0s 22ms/step - loss: 6.0240e-04 - accuracy: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 26ms/step - loss: 1.4598e-05 - accuracy: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 31ms/step - loss: 2.2942e-05 - accuracy: 1.0000

# %%
#BUILDING USEFUL FEATURES 
##For using our chatbot, we must implement the necessary functionality, which will be made easier by building a library of utility functions

def ourText(text): 
  newtkns = nltk.word_tokenize(text)
  newtkns = [lm.lemmatize(word) for word in newtkns]
  return newtkns

def wordBag(text, vocab): 
  newtkns = ourText(text)
  bagOwords = [0] * len(vocab)
  for w in newtkns: 
    for idx, word in enumerate(vocab):
      if word == w: 
        bagOwords[idx] = 1
  return np.array(bagOwords)

def pred_class(text, vocab, labels): 
  bagOwords = wordBag(text, vocab)
  ourResult = ourNewModel.predict(np.array([bagOwords]))[0]
  newThresh = 0.2
  yp = [[idx, res] for idx, res in enumerate(ourResult) if res > newThresh]

  yp.sort(key=lambda x: x[1], reverse=True)
  newList = []
  for r in yp:
    newList.append(labels[r[0]])
  return newList

def getRes(firstlist, fJson): 
  tag = firstlist[0]
  listOfIntents = fJson["intents"]
  for i in listOfIntents: 
    if i["tag"] == tag:
      ourResult = random.choice(i["responses"])
      break
  return ourResult

# %%
#user will be able to enter a query in a while loop, which will then be cleaned
#Next, we use our bag of words model to convert our text into numerical values and make a prediction about which tag in our intent the features most closely represent us

while True:
    newMessage = input("")
    intents = pred_class(newMessage, newWords, ourClasses)
    ourResult = getRes(intents, ourData)
    print(ourResult)
# Out:
# 1/1 [==============================] - 0s 151ms/step
# Namaste
# 1/1 [==============================] - 0s 24ms/step
# Hi there
# 1/1 [==============================] - 0s 22ms/step
# I am 2 years old and my birthday was yesterday
# 1/1 [==============================] - 0s 24ms/step
# I am 2 years old and my birthday was yesterday
